# %%
import math
import matplotlib.pyplot as plt 
from tabulate import tabulate

x=-4
xl=1.0
xu=3.0
xr=0.0
valores, funcion, tabla, raices, tabla, Eaprox, tabla1=[],[],[],[],[],[],[]
i=0
true=2.69556

while(x<=4):
    if(x==0):
        continue
    else:
        fx=(0.8-0.3*x)/x
        valores.append(x)
        funcion.append(fx)
        x+=0.1
    tabla.append([valores[i], funcion[i]])
    i+=1

def metodo1(dato):
    fn=(0.8-0.3*dato)/dato
    return fn

b=0
while (b<3):
    f1=metodo1(xl)
    f2=metodo1(xu)
    xr=xu-(f2*(xl-xu))/(f1-f2)
    raices.append(xr)
    f3=metodo1(xr)
    erpv=math.fabs(((true-xr)/true)*100)
    if(b==0):
        Eaprox.append("-----")
        eaprx=100
    else:
        k=b-1
        eaprx=math.fabs(((raices[b]-raices[k])/raices[b])*100)
        Eaprox.append(eaprx)
    tabla1.append([b+1,xr, str(erpv)+" %", str(Eaprox[b])+" %"])
    if ((f1*f3)<0):
        xu=xr
    if((f1*f3)>0):
         xl=xr  
    b+=1
    
plt.title("f(x)")
plt.axis([-4, 5, -6, 6])
plt.ylabel('f(x)')
plt.xlabel('x')
plt.axhline(0, color="black")
plt.plot(valores, funcion, 'r-', linewidth=2)
plt.plot(true,0, 'co', label='Raiz Exacta=2.69556')
plt.legend(loc = 'upper right', numpoints = 1)
plt.show()

print "\nDe manera analitica se obtiene:\n"
print tabulate(tabla, headers=["valor","funcion"])
print "\nUsando falsa posición con 3 iteraciones\n"
print tabulate(tabla1, headers=["Iteracion","Raiz","Erpv","Eaprox"])
# Out:
# De manera analitica se obtiene:
#
#        valor       funcion
# ------------  ------------
# -4            -0.5
# -3.9          -0.505128
# -3.8          -0.510526
# -3.7          -0.516216
# -3.6          -0.522222
# -3.5          -0.528571
# -3.4          -0.535294
# -3.3          -0.542424
# -3.2          -0.55
# -3.1          -0.558065
# -3            -0.566667
# -2.9          -0.575862
# -2.8          -0.585714
# -2.7          -0.596296
# -2.6          -0.607692
# -2.5          -0.62
# -2.4          -0.633333
# -2.3          -0.647826
# -2.2          -0.663636
# -2.1          -0.680952
# -2            -0.7
# -1.9          -0.721053
# -1.8          -0.744444
# -1.7          -0.770588
# -1.6          -0.8
# -1.5          -0.833333
# -1.4          -0.871429
# -1.3          -0.915385
# -1.2          -0.966667
# -1.1          -1.02727
# -1            -1.1
# -0.9          -1.18889
# -0.8          -1.3
# -0.7          -1.44286
# -0.6          -1.63333
# -0.5          -1.9
# -0.4          -2.3
# -0.3          -2.96667
# -0.2          -4.3
# -0.1          -8.3
#  2.41474e-15   3.31299e+14
#  0.1           7.7
#  0.2           3.7
#  0.3           2.36667
#  0.4           1.7
#  0.5           1.3
#  0.6           1.03333
#  0.7           0.842857
#  0.8           0.7
#  0.9           0.588889
#  1             0.5
#  1.1           0.427273
#  1.2           0.366667
#  1.3           0.315385
#  1.4           0.271429
#  1.5           0.233333
#  1.6           0.2
#  1.7           0.170588
#  1.8           0.144444
#  1.9           0.121053
#  2             0.1
#  2.1           0.0809524
#  2.2           0.0636364
#  2.3           0.0478261
#  2.4           0.0333333
#  2.5           0.02
#  2.6           0.00769231
#  2.7          -0.0037037
#  2.8          -0.0142857
#  2.9          -0.0241379
#  3            -0.0333333
#  3.1          -0.0419355
#  3.2          -0.05
#  3.3          -0.0575758
#  3.4          -0.0647059
#  3.5          -0.0714286
#  3.6          -0.0777778
#  3.7          -0.0837838
#  3.8          -0.0894737
#  3.9          -0.0948718
#
# Usando falsa posición con 3 iteraciones
#
#   Iteracion     Raiz  Erpv             Eaprox
# -----------  -------  ---------------  ---------------
#           1  2.875    6.65687278339 %  ----- %
#           2  2.79688  3.75858819689 %  2.79329608939 %
#           3  2.74805  1.94716033032 %  1.77683013504 %
